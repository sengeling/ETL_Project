# %%
import pandas as pd
from sqlalchemy import create_engine
import pymysql
pymysql.install_as_MySQLdb()

# %% [markdown]
# # Store F1 Data into a DataFrame
#
# 1. Original Data source 1 (FORMAT: CSV): Formula 1 race data - Formula 1 Race Data from 1950 to 2017 https://www.kaggle.com/cjgdev/formula-1-race-data-19502017
#
# Four csvs used:
# 1. circuits.csv: Contains a list of every formula 1 circuit, including name, location and geographic data.
# 2. drivers.csv: Contains a list of every Formula 1 driver, including full name, dob, and nationality.
# 3. races.csv: Details of every race, including year, date, time, circuit and round
# 4. results.csv: The results for each driver in each race

# %%
# Read in F1 Grand Prix data from https://www.kaggle.com/cjgdev/formula-1-race-data-19502017
races_csv = pd.read_csv("resources/f1_csvs/races.csv") 
results_csv = pd.read_csv("resources/f1_csvs/results.csv")
circuits_csv = pd.read_csv("resources/f1_csvs/circuits.csv")
drivers_csv = pd.read_csv("resources/f1_csvs/drivers.csv")

# %% [markdown]
# # Clean F1 Data
#
# 1. Get rid of unknown or uncommon races and only pull US races from circuits.csv and races.csv and then merge them
# 2. Merge drivers and results csvs on driver id
# 3. combine the two merged dataframes, drop unwanted columns, rename poorly named columns

# %%
# Set the index for the circuits csv to circuitId
circuits_csv = circuits_csv.set_index('circuitId')

# Locate only circuits in the US
circuits_csv = circuits_csv.loc[circuits_csv['country'] == 'USA']

# drop uncommon or unknown US circuits based on circuitId (Index)
circuits_csv = circuits_csv.drop([37, 42, 43, 44, 72])

# Reset the index to make merging easier later
circuits_csv = circuits_csv.reset_index()

circuits_csv.head()
# Out:
#    circuitId    circuitRef                             name        location  \
# 0         19  indianapolis      Indianapolis Motor Speedway    Indianapolis
# 1         33       phoenix           Phoenix street circuit         Phoenix
# 2         46  watkins_glen                     Watkins Glen  New York State
# 3         60     riverside  Riverside International Raceway      California
# 4         63       sebring    Sebring International Raceway         Florida
#
#   country      lat       lng  alt  \
# 0     USA  39.7950  -86.2347  NaN
# 1     USA  33.4479 -112.0750  NaN
# 2     USA  42.3369  -76.9272  NaN
# 3     USA  33.9370 -117.2730  NaN
# 4     USA  27.4547  -81.3483  NaN
#
#                                                  url
# 0  http://en.wikipedia.org/wiki/Indianapolis_Moto...
# 1  http://en.wikipedia.org/wiki/Phoenix_street_ci...
# 2  http://en.wikipedia.org/wiki/Watkins_Glen_Inte...
# 3  http://en.wikipedia.org/wiki/Riverside_Interna...
# 4       http://en.wikipedia.org/wiki/Sebring_Raceway

# %%
# Remove uncommon or unknown US circuits
races_csv = races_csv.loc[races_csv['circuitId'] != 43]

# Save only US Races
races_csv = races_csv.loc[races_csv['name'].isin(['United States Grand Prix', 'United States Grand Prix West'])]
races_csv.head()
# Out:
#      raceId  year  round  circuitId                      name       date  \
# 41       42  2007      7         19  United States Grand Prix  6/17/2007
# 61       62  2006     10         19  United States Grand Prix   7/2/2006
# 78       79  2005      9         19  United States Grand Prix  6/19/2005
# 97       98  2004      9         19  United States Grand Prix  6/20/2004
# 121     122  2003     15         19  United States Grand Prix  9/28/2003
#
#          time                                                url
# 41   17:00:00  http://en.wikipedia.org/wiki/2007_United_State...
# 61   14:00:00  http://en.wikipedia.org/wiki/2006_United_State...
# 78   14:00:00  http://en.wikipedia.org/wiki/2005_United_State...
# 97        NaN  http://en.wikipedia.org/wiki/2004_United_State...
# 121       NaN  http://en.wikipedia.org/wiki/2003_United_State...

# %%
# Combine the circuits and races dfs
cir_race = pd.merge(circuits_csv, races_csv, on='circuitId')
cir_race.head()
# Out:
#    circuitId    circuitRef                       name_x      location country  \
# 0         19  indianapolis  Indianapolis Motor Speedway  Indianapolis     USA
# 1         19  indianapolis  Indianapolis Motor Speedway  Indianapolis     USA
# 2         19  indianapolis  Indianapolis Motor Speedway  Indianapolis     USA
# 3         19  indianapolis  Indianapolis Motor Speedway  Indianapolis     USA
# 4         19  indianapolis  Indianapolis Motor Speedway  Indianapolis     USA
#
#       lat      lng  alt                                              url_x  \
# 0  39.795 -86.2347  NaN  http://en.wikipedia.org/wiki/Indianapolis_Moto...
# 1  39.795 -86.2347  NaN  http://en.wikipedia.org/wiki/Indianapolis_Moto...
# 2  39.795 -86.2347  NaN  http://en.wikipedia.org/wiki/Indianapolis_Moto...
# 3  39.795 -86.2347  NaN  http://en.wikipedia.org/wiki/Indianapolis_Moto...
# 4  39.795 -86.2347  NaN  http://en.wikipedia.org/wiki/Indianapolis_Moto...
#
#    raceId  year  round                    name_y       date      time  \
# 0      42  2007      7  United States Grand Prix  6/17/2007  17:00:00
# 1      62  2006     10  United States Grand Prix   7/2/2006  14:00:00
# 2      79  2005      9  United States Grand Prix  6/19/2005  14:00:00
# 3      98  2004      9  United States Grand Prix  6/20/2004       NaN
# 4     122  2003     15  United States Grand Prix  9/28/2003       NaN
#
#                                                url_y
# 0  http://en.wikipedia.org/wiki/2007_United_State...
# 1  http://en.wikipedia.org/wiki/2006_United_State...
# 2  http://en.wikipedia.org/wiki/2005_United_State...
# 3  http://en.wikipedia.org/wiki/2004_United_State...
# 4  http://en.wikipedia.org/wiki/2003_United_State...

# %%
# Combine the drivers and the results dfs
dri_res = pd.merge(drivers_csv, results_csv, on='driverId')
dri_res.head()
# Out:
#    driverId driverRef  number_x code forename   surname       dob nationality  \
# 0         1  hamilton      44.0  HAM    Lewis  Hamilton  7/1/1985     British
# 1         1  hamilton      44.0  HAM    Lewis  Hamilton  7/1/1985     British
# 2         1  hamilton      44.0  HAM    Lewis  Hamilton  7/1/1985     British
# 3         1  hamilton      44.0  HAM    Lewis  Hamilton  7/1/1985     British
# 4         1  hamilton      44.0  HAM    Lewis  Hamilton  7/1/1985     British
#
#                                            url  resultId   ...     \
# 0  http://en.wikipedia.org/wiki/Lewis_Hamilton         1   ...
# 1  http://en.wikipedia.org/wiki/Lewis_Hamilton        27   ...
# 2  http://en.wikipedia.org/wiki/Lewis_Hamilton        57   ...
# 3  http://en.wikipedia.org/wiki/Lewis_Hamilton        69   ...
# 4  http://en.wikipedia.org/wiki/Lewis_Hamilton        90   ...
#
#    positionOrder  points  laps     time  milliseconds fastestLap  rank  \
# 0              1    10.0    58  34:50.6     5690616.0       39.0   2.0
# 1              5     4.0    56   46.548     5525103.0       53.0   3.0
# 2             13     0.0    56      NaN           NaN       25.0  19.0
# 3              3     6.0    66    4.187     5903238.0       20.0   3.0
# 4              2     8.0    58    3.779     5213230.0       31.0   2.0
#
#    fastestLapTime  fastestLapSpeed statusId
# 0         01:27.5            218.3        1
# 1         01:35.5          209.033        1
# 2         01:35.5          203.969       11
# 3         01:22.0          204.323        1
# 4         01:26.5          222.085        1
#
# [5 rows x 26 columns]

# %%
# combine the circuits/race df and the driver/results df into one final combined df
combined_df = pd.merge(cir_race, dri_res, on='raceId')
combined_df = combined_df.drop(columns=['circuitRef', 'lat', 'lng', 'alt', 'url_x', 'url_y', 'url', 'name_y', 'time_x', 'round', 'constructorId', 'number_y', 'grid', 'position', 'positionText', 'milliseconds',
       'fastestLap', 'statusId', 'rank', 'resultId', 'number_x', 'driverRef', 'code'])

# Rename columns to something more meaningful
combined_df = combined_df.rename(columns={'name_x':'trackName',
                          'forename':'firstName',
                          'time_y':'driverRaceTime'})
combined_df.head()
# Out:
#    circuitId                    trackName      location country  raceId  year  \
# 0         19  Indianapolis Motor Speedway  Indianapolis     USA      42  2007
# 1         19  Indianapolis Motor Speedway  Indianapolis     USA      42  2007
# 2         19  Indianapolis Motor Speedway  Indianapolis     USA      42  2007
# 3         19  Indianapolis Motor Speedway  Indianapolis     USA      42  2007
# 4         19  Indianapolis Motor Speedway  Indianapolis     USA      42  2007
#
#         date  driverId firstName     surname         dob nationality  \
# 0  6/17/2007         1     Lewis    Hamilton    7/1/1985     British
# 1  6/17/2007         2      Nick    Heidfeld   10/5/1977      German
# 2  6/17/2007         3      Nico     Rosberg  27/06/1985      German
# 3  6/17/2007         4  Fernando      Alonso  29/07/1981     Spanish
# 4  6/17/2007         5    Heikki  Kovalainen  19/10/1981     Finnish
#
#    positionOrder  points  laps driverRaceTime fastestLapTime fastestLapSpeed
# 0              1    10.0    73        31:10.0        01:13.2         206.101
# 1             18     0.0    56            NaN        01:13.4         205.562
# 2             16     0.0    68            NaN        01:14.1         203.753
# 3              2     8.0    73            1.5        01:13.3         206.003
# 4              5     4.0    73           41.4        01:14.0          203.94

# %% [markdown]
# # Store Weather Data into a DataFrame
#
# 2. Original Data source 2 (FORMAT: NOT YET KNOWN): Weather data is the Local Climatologcial Data from NOAA.gov - https://www.ncdc.noaa.gov/data-access/land-based-station-data/land-based-datasets/quality-controlled-local-climatological-data-qclcd

# %%
# Create dataframe from csv
austin_weather = pd.read_csv('resources/weather_csvs/austin_weather.csv')
indy_weather = pd.read_csv('resources/weather_csvs/indy_weather.csv')
# Out:
# C:\Users\sengeling\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3020: DtypeWarning: Columns (33,34,41,42,43,46,49,56,73,75,76,88,89) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# C:\Users\sengeling\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3020: DtypeWarning: Columns (3,19,25,26,27,28,29,30,31,33,34,41,42,43,46,48,49,51,52,53,56,58,59,60,61,63,69,71,73,75,76,77,82,88,89,95,111,112,113,114,115,116,117,118,119) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %% [markdown]
# # Clean Weather Data

# %%
# Keep only the rows with code type 'SOD' (indicating daily weather data) in the 'REPORT_TYPE' column
austin_weather = austin_weather.loc[austin_weather['REPORT_TYPE'].str.strip() == 'SOD']

# Drop all columns that have all NaN values
austin_weather.dropna(axis=1, how='all', inplace=True)

# Add column that clarifies the city name
austin_weather['city'] = 'Austin, TX'

# From the remaining columns, keep the ones specified
austin_weather = austin_weather[['STATION', 'DATE', 'city', 'DailyAverageDryBulbTemperature', 'DailyAverageRelativeHumidity', 
                          'DailyAverageStationPressure', 'DailyAverageWindSpeed', 'DailyMaximumDryBulbTemperature', 
                          'DailyMinimumDryBulbTemperature', 'DailyPeakWindDirection', 'DailyPrecipitation']]

# Rename columns, reset index
austin_weather.columns = ['station', 'date', 'city', 'avg_temp', 'avg_rel_humidity', 'avg_pressure', 'avg_wind', 'max_temp',
                         'min_temp', 'peak_wind_dir', 'precip']

austin_weather.reset_index(drop=True, inplace=True)

# Clean the 'date' column by keeping only the date ('YYYY-MM-DD') and dropping extra info (time entered)
austin_weather['date'] = [austin_weather['date'][x][:10] for x in range(len(austin_weather['date']))]

# Instantiate list of dates
austin_dates = ['2012-11-18', '2013-11-17', '2014-11-02', '2015-10-25', '2016-10-23', '2017-10-22', '2018-10-21']

# Keep only rows whose date is in the list austin_dates and reset the index again
austin_weather = austin_weather.loc[austin_weather['date'].isin(austin_dates)]

austin_weather.reset_index(drop=True, inplace=True)

# Show dataframe
austin_weather
# Out:
#        station        date        city  avg_temp  avg_rel_humidity  \
# 0  72254013904  2012-11-18  Austin, TX      55.0              65.0
# 1  72254013904  2013-11-17  Austin, TX      75.0              78.0
# 2  72254013904  2014-11-02  Austin, TX      57.0              64.0
# 3  72254013904  2015-10-25  Austin, TX      62.0              88.0
# 4  72254013904  2016-10-23  Austin, TX      66.0              68.0
# 5  72254013904  2017-10-22  Austin, TX      64.0              81.0
# 6  72254013904  2018-10-21  Austin, TX      65.0              61.0
#
#    avg_pressure  avg_wind  max_temp  min_temp  peak_wind_dir precip
# 0         29.70       4.6      74.0      36.0          160.0   0.00
# 1         29.33       5.0      89.0      61.0          200.0   0.00
# 2         29.68       8.6      76.0      38.0          150.0   0.00
# 3         29.47      16.7      65.0      58.0          350.0   0.57
# 4         29.62       5.6      84.0      47.0          180.0   0.01
# 5         29.57       8.2      78.0      50.0          330.0   0.70
# 6         29.70       9.6      74.0      55.0           20.0   0.00

# %%
# Keep only the rows with code type 'SOD' (indicating daily weather data) in the 'REPORT_TYPE' column
indy_weather = indy_weather.loc[indy_weather['REPORT_TYPE'].str.strip() == 'SOD']

# Drop all columns that have all NaN values
indy_weather.dropna(axis=1, how='all', inplace=True)

# Add column that clarifies the city name
indy_weather['city'] = 'Indianapolis, IN'

# From the remaining columns, keep the ones specified
indy_weather = indy_weather[['STATION', 'DATE', 'city', 'DailyAverageDryBulbTemperature', 'DailyAverageRelativeHumidity', 
                          'DailyAverageStationPressure', 'DailyAverageWindSpeed', 'DailyMaximumDryBulbTemperature', 
                          'DailyMinimumDryBulbTemperature', 'DailyPeakWindDirection', 'DailyPrecipitation']]

# Rename columns, reset index
indy_weather.columns = ['station', 'date', 'city', 'avg_temp', 'avg_rel_humidity', 'avg_pressure', 'avg_wind', 'max_temp',
                         'min_temp', 'peak_wind_dir', 'precip']

indy_weather.reset_index(drop=True, inplace=True)

# Clean the 'date' column by keeping only the date ('YYYY-MM-DD') and dropping extra info (time entered)
indy_weather['date'] = [indy_weather['date'][x][:10] for x in range(len(indy_weather['date']))]

# Instantiate list of dates
indy_dates = ['2000-09-24', '2001-09-30', '2002-09-29', '2003-09-28', '2004-06-20', '2005-06-19', 
              '2006-07-02', '2007-06-17']

# Keep only rows whose date is in the list austin_dates and reset the index again
indy_weather = indy_weather.loc[indy_weather['date'].isin(indy_dates)]

indy_weather.reset_index(drop=True, inplace=True)

# Show dataframe
indy_weather
# Out:
#        station        date              city avg_temp  avg_rel_humidity  \
# 0  72438093819  2000-09-24  Indianapolis, IN       59               NaN
# 1  72438093819  2001-09-30  Indianapolis, IN       59               NaN
# 2  72438093819  2002-09-29  Indianapolis, IN       69               NaN
# 3  72438093819  2003-09-28  Indianapolis, IN       50               NaN
# 4  72438093819  2004-06-20  Indianapolis, IN       63               NaN
# 5  72438093819  2005-06-19  Indianapolis, IN       67               NaN
# 6  72438093819  2006-07-02  Indianapolis, IN       80              63.0
# 7  72438093819  2007-06-17  Indianapolis, IN       82              49.0
#
#    avg_pressure  avg_wind max_temp min_temp peak_wind_dir precip
# 0         29.08      10.9       63       55           330   0.23
# 1         29.34       6.8       72       46           360  0.00s
# 2         29.24       6.8       80       57           190  0.00s
# 3         29.05       8.9       56       44           320   0.07
# 4         29.21       6.0       75       51           250  0.00s
# 5         29.26       8.1       77       57           040   0.00
# 6         29.21      10.0       90       70           270   0.00
# 7         29.15       7.8       93       71           260      T

# %% [markdown]
# # Combine the Weather DataFrames
# Commented out as a failsafe.

# %%
# Save dataframe to a csv file
# indy_weather.to_csv('weather_csvs/weather_data.csv', index=False)

# %%
# Append the other dataframe to the weather_data csv
# with open('weather_csvs/weather_data.csv', 'a') as file:
#     austin_weather.to_csv(file, header=False, index=False)

# %%
# Create dataframe from the weather_data csv
combined_weather = pd.read_csv('resources/weather_csvs/weather_data.csv')

combined_weather
# Out:
#         station        date              city  avg_temp  avg_rel_humidity  \
# 0   72438093819   9/24/2000  Indianapolis, IN        59               NaN
# 1   72438093819   9/30/2001  Indianapolis, IN        59               NaN
# 2   72438093819   9/29/2002  Indianapolis, IN        69               NaN
# 3   72438093819   9/28/2003  Indianapolis, IN        50               NaN
# 4   72438093819   6/20/2004  Indianapolis, IN        63               NaN
# 5   72438093819   6/19/2005  Indianapolis, IN        67               NaN
# 6   72438093819    7/2/2006  Indianapolis, IN        80              63.0
# 7   72438093819   6/17/2007  Indianapolis, IN        82              49.0
# 8   72254013904  11/18/2012        Austin, TX        55              65.0
# 9   72254013904  11/17/2013        Austin, TX        75              78.0
# 10  72254013904   11/2/2014        Austin, TX        57              64.0
# 11  72254013904  10/25/2015        Austin, TX        62              88.0
# 12  72254013904  10/23/2016        Austin, TX        66              68.0
# 13  72254013904  10/22/2017        Austin, TX        64              81.0
# 14  72254013904  10/21/2018        Austin, TX        65              61.0
#
#     avg_pressure  avg_wind  max_temp  min_temp  peak_wind_dir precip
# 0          29.08      10.9        63        55            330   0.23
# 1          29.34       6.8        72        46            360  0.00s
# 2          29.24       6.8        80        57            190  0.00s
# 3          29.05       8.9        56        44            320   0.07
# 4          29.21       6.0        75        51            250  0.00s
# 5          29.26       8.1        77        57             40      0
# 6          29.21      10.0        90        70            270      0
# 7          29.15       7.8        93        71            260      T
# 8          29.70       4.6        74        36            160      0
# 9          29.33       5.0        89        61            200      0
# 10         29.68       8.6        76        38            150      0
# 11         29.47      16.7        65        58            350   0.57
# 12         29.62       5.6        84        47            180   0.01
# 13         29.57       8.2        78        50            330    0.7
# 14         29.70       9.6        74        55             20      0

# %% [markdown]
# # Create Database
# Done in Stephanie's Workbench - f1_weather_db.

# %% [markdown]
# # Connect to Local
#
# Relational database, chosen in order to join two different types of data on a common key - date

# %%
# Connect to the database
rds_connection_string = "root:Stup!dR00tP@55w0rd@127.0.0.1/f1_weather_db"
engine = create_engine(f'mysql://{rds_connection_string}')

# %% [markdown]
# # Use Pandas to Load Race Data into Database as a Table
# f1_data

# %%
# Add the combined f1 dataframe to the database
combined_df.to_sql(name='f1_data', con=engine, if_exists='append', index=False)

# %% [markdown]
# # Use Pandas to Load Weather Data into Database as a Table
# weather_data

# %%
combined_weather.to_sql(name='weather_data', con=engine, if_exists='append', index=False)

# %% [markdown]
# # Confirm Data Has Been Loaded

# %%
# Test that the f1 table is presnt and working
pd.read_sql_query('select * from f1_data', con=engine).head()
# Out:
#    circuitId                    trackName      location country  raceId  year  \
# 0         19  Indianapolis Motor Speedway  Indianapolis     USA      42  2007
# 1         19  Indianapolis Motor Speedway  Indianapolis     USA      42  2007
# 2         19  Indianapolis Motor Speedway  Indianapolis     USA      42  2007
# 3         19  Indianapolis Motor Speedway  Indianapolis     USA      42  2007
# 4         19  Indianapolis Motor Speedway  Indianapolis     USA      42  2007
#
#         date  driverId firstName     surname         dob nationality  \
# 0  6/17/2007         1     Lewis    Hamilton    7/1/1985     British
# 1  6/17/2007         2      Nick    Heidfeld   10/5/1977      German
# 2  6/17/2007         3      Nico     Rosberg  27/06/1985      German
# 3  6/17/2007         4  Fernando      Alonso  29/07/1981     Spanish
# 4  6/17/2007         5    Heikki  Kovalainen  19/10/1981     Finnish
#
#    positionOrder  points  laps driverRaceTime fastestLapTime fastestLapSpeed
# 0              1    10.0    73        31:10.0        01:13.2         206.101
# 1             18     0.0    56           None        01:13.4         205.562
# 2             16     0.0    68           None        01:14.1         203.753
# 3              2     8.0    73            1.5        01:13.3         206.003
# 4              5     4.0    73           41.4        01:14.0          203.94

# %%
# Test that the weather table is presnt and working
pd.read_sql_query('select * from weather_data', con=engine).head()
# Out:
#        station       date              city  avg_temp  avg_rel_humidity  \
# 0  72438093819  9/24/2000  Indianapolis, IN        59               NaN
# 1  72438093819  9/30/2001  Indianapolis, IN        59               NaN
# 2  72438093819  9/29/2002  Indianapolis, IN        69               NaN
# 3  72438093819  9/28/2003  Indianapolis, IN        50               NaN
# 4  72438093819  6/20/2004  Indianapolis, IN        63               NaN
#
#    avg_pressure  avg_wind  max_temp  min_temp  peak_wind_dir precip
# 0         29.08      10.9        63        55            330   0.23
# 1         29.34       6.8        72        46            360  0.00s
# 2         29.24       6.8        80        57            190  0.00s
# 3         29.05       8.9        56        44            320   0.07
# 4         29.21       6.0        75        51            250  0.00s

# %% [markdown]
# # Test a Join on Date

# %%
pd.read_sql_query('select    f1_data.trackName,\
                             f1_data.location,\
                             f1_data.date,\
                             f1_data.firstName,\
                             f1_data.surname,\
                             f1_data.positionOrder,\
                             f1_data.driverRaceTime,\
                             f1_data.fastestLapTime,\
                             f1_data.fastestLapSpeed,\
                             weather_data.date,\
                             weather_data.avg_temp,\
                             weather_data.avg_rel_humidity,\
                             weather_data.avg_wind,\
                             weather_data.peak_wind_dir,\
                             weather_data.precip\
                    from     f1_data, weather_data\
                    where    f1_data.date = weather_data.date\
                    group by f1_data.surname, f1_data.date\
                    order by f1_data.date, f1_data.positionOrder;', con=engine)
# Out:
#                        trackName      location        date     firstName  \
# 0        Circuit of the Americas        Austin  10/22/2017         Lewis
# 1        Circuit of the Americas        Austin  10/22/2017     Sebastian
# 2        Circuit of the Americas        Austin  10/22/2017          Kimi
# 3        Circuit of the Americas        Austin  10/22/2017           Max
# 4        Circuit of the Americas        Austin  10/22/2017      Valtteri
# 5        Circuit of the Americas        Austin  10/22/2017       Esteban
# 6        Circuit of the Americas        Austin  10/22/2017        Carlos
# 7        Circuit of the Americas        Austin  10/22/2017        Sergio
# 8        Circuit of the Americas        Austin  10/22/2017        Felipe
# 9        Circuit of the Americas        Austin  10/22/2017        Daniil
# 10       Circuit of the Americas        Austin  10/22/2017         Lance
# 11       Circuit of the Americas        Austin  10/22/2017       Stoffel
# 12       Circuit of the Americas        Austin  10/22/2017       Brendon
# 13       Circuit of the Americas        Austin  10/22/2017        Romain
# 14       Circuit of the Americas        Austin  10/22/2017        Marcus
# 15       Circuit of the Americas        Austin  10/22/2017         Kevin
# 16       Circuit of the Americas        Austin  10/22/2017      Fernando
# 17       Circuit of the Americas        Austin  10/22/2017        Daniel
# 18       Circuit of the Americas        Austin  10/22/2017        Pascal
# 19       Circuit of the Americas        Austin  10/22/2017          Nico
# 20       Circuit of the Americas        Austin  10/23/2016         Lewis
# 21       Circuit of the Americas        Austin  10/23/2016          Nico
# 22       Circuit of the Americas        Austin  10/23/2016        Daniel
# 23       Circuit of the Americas        Austin  10/23/2016     Sebastian
# 24       Circuit of the Americas        Austin  10/23/2016      Fernando
# 25       Circuit of the Americas        Austin  10/23/2016        Carlos
# 26       Circuit of the Americas        Austin  10/23/2016        Felipe
# 27       Circuit of the Americas        Austin  10/23/2016        Sergio
# 28       Circuit of the Americas        Austin  10/23/2016        Jenson
# 29       Circuit of the Americas        Austin  10/23/2016        Romain
# ..                           ...           ...         ...           ...
# 258  Indianapolis Motor Speedway  Indianapolis   9/29/2002       Olivier
# 259  Indianapolis Motor Speedway  Indianapolis   9/29/2002  Heinz-Harald
# 260  Indianapolis Motor Speedway  Indianapolis   9/29/2002          Mika
# 261  Indianapolis Motor Speedway  Indianapolis   9/29/2002         Allan
# 262  Indianapolis Motor Speedway  Indianapolis   9/29/2002          Ralf
# 263  Indianapolis Motor Speedway  Indianapolis   9/29/2002          Kimi
# 264  Indianapolis Motor Speedway  Indianapolis   9/29/2002          Alex
# 265  Indianapolis Motor Speedway  Indianapolis   9/29/2002          Mark
# 266  Indianapolis Motor Speedway  Indianapolis   9/29/2002         Pedro
# 267  Indianapolis Motor Speedway  Indianapolis   9/30/2001          Mika
# 268  Indianapolis Motor Speedway  Indianapolis   9/30/2001         David
# 269  Indianapolis Motor Speedway  Indianapolis   9/30/2001         Jarno
# 270  Indianapolis Motor Speedway  Indianapolis   9/30/2001         Eddie
# 271  Indianapolis Motor Speedway  Indianapolis   9/30/2001          Nick
# 272  Indianapolis Motor Speedway  Indianapolis   9/30/2001          Jean
# 273  Indianapolis Motor Speedway  Indianapolis   9/30/2001     Giancarlo
# 274  Indianapolis Motor Speedway  Indianapolis   9/30/2001        Jenson
# 275  Indianapolis Motor Speedway  Indianapolis   9/30/2001  Heinz-Harald
# 276  Indianapolis Motor Speedway  Indianapolis   9/30/2001       Olivier
# 277  Indianapolis Motor Speedway  Indianapolis   9/30/2001         Pedro
# 278  Indianapolis Motor Speedway  Indianapolis   9/30/2001       Enrique
# 279  Indianapolis Motor Speedway  Indianapolis   9/30/2001       TomÌÁÁ
# 280  Indianapolis Motor Speedway  Indianapolis   9/30/2001        Rubens
# 281  Indianapolis Motor Speedway  Indianapolis   9/30/2001       Jacques
# 282  Indianapolis Motor Speedway  Indianapolis   9/30/2001           Jos
# 283  Indianapolis Motor Speedway  Indianapolis   9/30/2001          Juan
# 284  Indianapolis Motor Speedway  Indianapolis   9/30/2001          Alex
# 285  Indianapolis Motor Speedway  Indianapolis   9/30/2001          Ralf
# 286  Indianapolis Motor Speedway  Indianapolis   9/30/2001      Fernando
# 287  Indianapolis Motor Speedway  Indianapolis   9/30/2001          Kimi
#
#            surname  positionOrder driverRaceTime fastestLapTime  \
# 0         Hamilton              1        33:51.0        01:38.8
# 1           Vettel              2         10.143        01:38.8
# 2      RÌ_ikkÌ¦nen              3         15.779        01:37.8
# 3       Verstappen              4         16.768        01:38.1
# 4           Bottas              5         34.967        01:37.8
# 5             Ocon              6      +1:30.980        01:40.5
# 6            Sainz              7      +1:32.944        01:40.5
# 7           PÌ©rez              8           None        01:40.9
# 8            Massa              9           None        01:40.1
# 9            Kvyat             10           None        01:41.0
# 10          Stroll             11           None        01:39.7
# 11       Vandoorne             12           None        01:40.3
# 12         Hartley             13           None        01:40.0
# 13        Grosjean             14           None        01:41.3
# 14        Ericsson             15           None        01:41.0
# 15       Magnussen             16           None        01:37.9
# 16          Alonso             17           None        01:41.5
# 17       Ricciardo             18           None        01:40.1
# 18        Wehrlein             19           None        01:47.1
# 19     HÌ_lkenberg             20           None        01:44.3
# 20        Hamilton              1        38:12.6        01:42.4
# 21         Rosberg              2           4.52        01:41.9
# 22       Ricciardo              3         19.692        01:42.6
# 23          Vettel              4         43.134        01:39.9
# 24          Alonso              5      +1:33.953        01:43.5
# 25           Sainz              6      +1:36.124        01:42.8
# 26           Massa              7           None        01:43.4
# 27          PÌ©rez              8           None        01:43.9
# 28          Button              9           None        01:44.5
# 29        Grosjean             10           None        01:44.3
# ..             ...            ...            ...            ...
# 258          Panis             12           None           None
# 259       Frentzen             13           None           None
# 260           Salo             14           None           None
# 261         McNish             15           None           None
# 262     Schumacher             16           None           None
# 263    RÌ_ikkÌ¦nen             17           None           None
# 264          Yoong             18           None           None
# 265         Webber             19           None           None
# 266     de la Rosa             20           None           None
# 267      HÌ_kkinen              1        32:42.8           None
# 268      Coulthard              3         12.043           None
# 269         Trulli              4         57.423           None
# 270         Irvine              5      +1:12.434           None
# 271       Heidfeld              6      +1:12.996           None
# 272          Alesi              7           None           None
# 273     Fisichella              8           None           None
# 274         Button              9           None           None
# 275       Frentzen             10           None           None
# 276          Panis             11           None           None
# 277     de la Rosa             12           None           None
# 278       Bernoldi             13           None           None
# 279           Enge             14           None           None
# 280    Barrichello             15           None           None
# 281     Villeneuve             16           None           None
# 282     Verstappen             17           None           None
# 283  Pablo Montoya             18           None           None
# 284          Yoong             19           None           None
# 285     Schumacher             20           None           None
# 286         Alonso             21           None           None
# 287    RÌ_ikkÌ¦nen             22           None           None
#
#     fastestLapSpeed        date  avg_temp  avg_rel_humidity  avg_wind  \
# 0           200.927  10/22/2017        64              81.0       8.2
# 1            200.86  10/22/2017        64              81.0       8.2
# 2           203.003  10/22/2017        64              81.0       8.2
# 3           202.394  10/22/2017        64              81.0       8.2
# 4           203.001  10/22/2017        64              81.0       8.2
# 5           197.482  10/22/2017        64              81.0       8.2
# 6           197.555  10/22/2017        64              81.0       8.2
# 7           196.793  10/22/2017        64              81.0       8.2
# 8           198.208  10/22/2017        64              81.0       8.2
# 9           196.559  10/22/2017        64              81.0       8.2
# 10          199.133  10/22/2017        64              81.0       8.2
# 11          197.777  10/22/2017        64              81.0       8.2
# 12          198.509  10/22/2017        64              81.0       8.2
# 13              196  10/22/2017        64              81.0       8.2
# 14          196.423  10/22/2017        64              81.0       8.2
# 15          202.739  10/22/2017        64              81.0       8.2
# 16          195.463  10/22/2017        64              81.0       8.2
# 17          198.265  10/22/2017        64              81.0       8.2
# 18          185.357  10/22/2017        64              81.0       8.2
# 19           190.34  10/22/2017        64              81.0       8.2
# 20          193.842  10/23/2016        66              68.0       5.6
# 21          194.773  10/23/2016        66              68.0       5.6
# 22          193.523  10/23/2016        66              68.0       5.6
# 23          198.712  10/23/2016        66              68.0       5.6
# 24          191.752  10/23/2016        66              68.0       5.6
# 25          193.002  10/23/2016        66              68.0       5.6
# 26          191.915  10/23/2016        66              68.0       5.6
# 27          190.972  10/23/2016        66              68.0       5.6
# 28          189.979  10/23/2016        66              68.0       5.6
# 29          190.221  10/23/2016        66              68.0       5.6
# ..              ...         ...       ...               ...       ...
# 258            None   9/29/2002        69               NaN       6.8
# 259            None   9/29/2002        69               NaN       6.8
# 260            None   9/29/2002        69               NaN       6.8
# 261            None   9/29/2002        69               NaN       6.8
# 262            None   9/29/2002        69               NaN       6.8
# 263            None   9/29/2002        69               NaN       6.8
# 264            None   9/29/2002        69               NaN       6.8
# 265            None   9/29/2002        69               NaN       6.8
# 266            None   9/29/2002        69               NaN       6.8
# 267            None   9/30/2001        59               NaN       6.8
# 268            None   9/30/2001        59               NaN       6.8
# 269            None   9/30/2001        59               NaN       6.8
# 270            None   9/30/2001        59               NaN       6.8
# 271            None   9/30/2001        59               NaN       6.8
# 272            None   9/30/2001        59               NaN       6.8
# 273            None   9/30/2001        59               NaN       6.8
# 274            None   9/30/2001        59               NaN       6.8
# 275            None   9/30/2001        59               NaN       6.8
# 276            None   9/30/2001        59               NaN       6.8
# 277            None   9/30/2001        59               NaN       6.8
# 278            None   9/30/2001        59               NaN       6.8
# 279            None   9/30/2001        59               NaN       6.8
# 280            None   9/30/2001        59               NaN       6.8
# 281            None   9/30/2001        59               NaN       6.8
# 282            None   9/30/2001        59               NaN       6.8
# 283            None   9/30/2001        59               NaN       6.8
# 284            None   9/30/2001        59               NaN       6.8
# 285            None   9/30/2001        59               NaN       6.8
# 286            None   9/30/2001        59               NaN       6.8
# 287            None   9/30/2001        59               NaN       6.8
#
#      peak_wind_dir precip
# 0              330    0.7
# 1              330    0.7
# 2              330    0.7
# 3              330    0.7
# 4              330    0.7
# 5              330    0.7
# 6              330    0.7
# 7              330    0.7
# 8              330    0.7
# 9              330    0.7
# 10             330    0.7
# 11             330    0.7
# 12             330    0.7
# 13             330    0.7
# 14             330    0.7
# 15             330    0.7
# 16             330    0.7
# 17             330    0.7
# 18             330    0.7
# 19             330    0.7
# 20             180   0.01
# 21             180   0.01
# 22             180   0.01
# 23             180   0.01
# 24             180   0.01
# 25             180   0.01
# 26             180   0.01
# 27             180   0.01
# 28             180   0.01
# 29             180   0.01
# ..             ...    ...
# 258            190  0.00s
# 259            190  0.00s
# 260            190  0.00s
# 261            190  0.00s
# 262            190  0.00s
# 263            190  0.00s
# 264            190  0.00s
# 265            190  0.00s
# 266            190  0.00s
# 267            360  0.00s
# 268            360  0.00s
# 269            360  0.00s
# 270            360  0.00s
# 271            360  0.00s
# 272            360  0.00s
# 273            360  0.00s
# 274            360  0.00s
# 275            360  0.00s
# 276            360  0.00s
# 277            360  0.00s
# 278            360  0.00s
# 279            360  0.00s
# 280            360  0.00s
# 281            360  0.00s
# 282            360  0.00s
# 283            360  0.00s
# 284            360  0.00s
# 285            360  0.00s
# 286            360  0.00s
# 287            360  0.00s
#
# [288 rows x 15 columns]
